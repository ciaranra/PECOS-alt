# %%
from pecos.qeclib.steane.steane_class import Steane

Steane
# Out:
# pecos.qeclib.steane.steane_class.Steane

# %%
from pecos.qeclib.steane.steane_class import Steane
from pecos.slr import Main, SlrConverter

prog = Main(
    c := Steane("c"),
    c.pz(),
)

print(SlrConverter(prog).guppy())

# %%
hugr = SlrConverter(prog).hugr()
